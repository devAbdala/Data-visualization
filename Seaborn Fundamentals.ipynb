# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# seaborn is a python library for data visualization like as matplotlib

# %%
survey = pd.read_csv("./data/young-people-survey-responses.csv" , index_col = 0)
survey
# Out:
#       Music  Techno  Movies  History  Mathematics  Pets  Spiders  Loneliness  \
# 0       5.0     1.0     5.0      1.0          3.0   4.0      1.0         3.0
# 1       4.0     1.0     5.0      1.0          5.0   5.0      1.0         2.0
# 2       5.0     1.0     5.0      1.0          5.0   5.0      1.0         5.0
# 3       5.0     2.0     5.0      4.0          4.0   1.0      5.0         5.0
# 4       5.0     2.0     5.0      3.0          2.0   1.0      1.0         3.0
# ...     ...     ...     ...      ...          ...   ...      ...         ...
# 1005    5.0     3.0     5.0      4.0          1.0   4.0      2.0         4.0
# 1006    4.0     4.0     5.0      4.0          5.0   5.0      1.0         1.0
# 1007    4.0     1.0     4.0      2.0          3.0   5.0      2.0         4.0
# 1008    5.0     2.0     5.0      3.0          1.0   4.0      3.0         3.0
# 1009    5.0     3.0     5.0      2.0          2.0   5.0      1.0         3.0
#
# ...

# %%
plt.figure(figsize = (10 , 4))
plt.style.use("seaborn-colorblind")
sns.countplot(x = "Internet usage" , data = survey)
plt.show()

# %%
plt.figure()
plt.style.use("seaborn-colorblind")
order = ['no time at all' , 'most of the day' , 'less than an hour a day' , 'few hours a day' ]
sns.catplot(x = "Internet usage" , data = survey , kind = 'count' , order = order)
plt.show()

# %%
insurance = pd.read_csv("./data/insurance.csv" , index_col = 0)
insurance
# Out:
#         sex   bmi  children smoker     region  expenses
# age
# 19   female  27.9         0    yes  southwest  16884.92
# 18     male  33.8         1     no  southeast   1725.55
# 28     male  33.0         3     no  southeast   4449.46
# 33     male  22.7         0     no  northwest  21984.47
# 32     male  28.9         0     no  northwest   3866.86
# ..      ...   ...       ...    ...        ...       ...
# 50     male  31.0         3     no  northwest  10600.55
# 18   female  31.9         0     no  northeast   2205.98
# 18   female  36.9         0     no  southeast   1629.83
# 21   female  25.8         0     no  southwest   2007.95
# 61   female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 6 columns]

# %%
plt.figure()
sns.boxplot(x = "sex" , y = "bmi" , data = insurance)
plt.show()

# %%
plt.figure()
sns.boxplot(x = "smoker" , y = "bmi" , data = insurance)
plt.show()

# %%
plt.figure()
sns.boxplot(x = "region" , y = "bmi" , data = insurance)
plt.show()

# %%
plt.figure(figsize = (10 , 4))
plt.style.use("seaborn-colorblind")
sns.countplot(x = "sex" , data = insurance )
plt.show()

# %%
plt.figure(figsize = (10 , 4))
plt.style.use("seaborn-colorblind")
sns.countplot(x = "sex" , data = insurance , hue = "smoker")
plt.show()

# %%
plt.figure()
sns.set_style('whitegrid')
sns.catplot(x = "sex" , y  = "bmi" , data = insurance , kind = 'point' , hue = 'smoker')
plt.show()

# %%
plt.figure()
sns.set_style('whitegrid')
sns.catplot(x = "sex" , y  = "expenses" , data = insurance , kind = 'point' , hue = 'smoker' )
plt.show()

# %%
plt.figure(figsize = (10 , 4))
plt.style.use("seaborn-colorblind")
hue_colors = {"yes" : "orange" , "no" : "blue"}
sns.scatterplot(x = "bmi" , y = "expenses" , data = insurance , hue = "smoker" , palette = hue_colors)
plt.show()

# %%
plt.figure(figsize = (10 , 4))
plt.style.use("seaborn-colorblind")
sns.scatterplot(x = "bmi" , y = "expenses" , data = insurance , hue = "region" )
plt.show()

# %%
plt.figure(figsize = (10 , 4))
plt.style.use("seaborn-colorblind")
sns.scatterplot(x = "bmi" , y = "expenses" , data = insurance , hue = "sex" , palette = "pastel" )
plt.show()

# %%
plt.figure(figsize = (10 , 4))
plt.style.use("bmh")
sns.relplot(x = "bmi" , y = 'expenses' , data = insurance , size = 'children' , kind = 'scatter' , hue = 'children' )
plt.show()

# %%
plt.figure(figsize = (10 , 4))
plt.style.use("bmh")
sns.relplot(x = "bmi" , y = 'expenses' , data = insurance  , kind = 'scatter' , hue = 'smoker' , style = 'smoker')
plt.show()

# %%
flights_delays = pd.read_csv("./data/flight_delays.csv" , index_col = 0 , parse_dates = True)
flights_delays
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
plt.figure(figsize = (20 , 4))
plt.style.use("bmh")
sns.lineplot(data = flights_delays , markers = True , dashes = False)
plt.show()

# %%
plt.figure(figsize = (20 , 10))
sns.heatmap(data = flights_delays , annot = True)
plt.show()

# %%
fifa = pd.read_csv("./data/fifa.csv" , index_col = 0 ,parse_dates = True )
fifa
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %%
plt.figure(figsize = (20 , 4))
sns.lineplot(x = fifa.index , y = fifa.ARG )
plt.show()

# %%
plt.figure(figsize = (20 , 4))
sns.lineplot(x = fifa.index , y = fifa.ARG , label = 'ARG' , color = 'blue')
sns.lineplot(x = fifa.index , y = fifa.BRA , label = 'BRA' , color = 'orange')
plt.show()

# %%
plt.figure(figsize = (20 , 4))
sns.set_style('darkgrid')
sns.lineplot(data = fifa , dashes = False )
plt.show()

# %%
shopify = pd.read_csv("./data/spotify.csv" , index_col=0)
shopify
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
plt.figure(figsize = (20 , 4))
sns.set_style('whitegrid')
sns.barplot(data = shopify )
plt.show()

# %%
plt.figure()
sns.set_style('whitegrid')
sns.catplot(data = shopify , kind = 'bar' )
plt.show()

# %%
plt.figure()
sns.set_style('whitegrid')
sns.catplot(data = shopify , kind = 'point' ) # join = False
plt.show()

# %%
iris = pd.read_csv("./data/Iris.csv" , index_col=0)
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
plt.figure()
sns.set_style('whitegrid')
sns.kdeplot(data = iris , fill = True)
plt.show()

# %%
plt.figure()
sns.set_style('whitegrid')
sns.kdeplot(x = iris['SepalLengthCm'] , fill = True)
plt.show()

# %%
plt.figure()
sns.set_style('whitegrid')
sns.kdeplot(x = iris['SepalLengthCm'] , fill = True , hue = iris['Species'])
plt.show()

# %%
plt.figure()
sns.set_style('whitegrid')
sns.jointplot(data = iris)
plt.show()

# %%
plt.figure()
sns.set_style('whitegrid')
sns.jointplot(data = iris , kind = 'kde')
plt.show()

# %%
plt.figure()
sns.set_style('whitegrid')
sns.histplot(data = iris , bins = 10)
plt.show()

# %%
plt.figure()
sns.set_style('whitegrid')
sns.histplot(x = iris['SepalLengthCm'] , hue = iris['Species'])
plt.show()

# %%
plt.figure()
sns.set_style('whitegrid')
sns.boxenplot(data = iris)
plt.show()

# %%
plt.figure()
sns.set_style('whitegrid')
sns.boxplot(data = iris)
plt.show()

# %%
dataframe = pd.read_csv("./data/countries-of-the-world.csv" , index_col = 0)
dataframe
# Out:
#                                               Region  Population  \
# Country
# Afghanistan            ASIA (EX. NEAR EAST)             31056997
# Albania          EASTERN EUROPE                          3581655
# Algeria          NORTHERN AFRICA                        32930091
# American Samoa   OCEANIA                                   57794
# Andorra          WESTERN EUROPE                            71201
# ...                                              ...         ...
# West Bank        NEAR EAST                               2460492
# Western Sahara   NORTHERN AFRICA                          273008
# Yemen            NEAR EAST                              21456188
# Zambia           SUB-SAHARAN AFRICA                     11502010
# Zimbabwe         SUB-SAHARAN AFRICA                     12236805
#
#                  Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan              647500                       48,0
# ...

# %%
dataframe['Region'].nunique()
# Out:
# 11

# %%
plt.figure(figsize = (20 , 5))
sns.set_style('darkgrid')
sns.scatterplot(x = 'GDP ($ per capita)' , y = 'Population' , data = dataframe , hue = 'Region')
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style('darkgrid')
sns.regplot(x = 'GDP ($ per capita)' , y = 'Population' , data = dataframe )
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style('darkgrid')
sns.lmplot(x = 'GDP ($ per capita)' , y = 'Population' , data = dataframe , hue = 'Region')
plt.show()

# %%
plt.figure(figsize = (15 , 5))
sns.set_palette("RdBu")
sns.set_context("paper")
sns.set_style('darkgrid')
sns.stripplot(x = 'Region' , y = 'GDP ($ per capita)' , data = dataframe )
plt.title("Stripplot")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# sns.set_palette(
#        "RdBu" , "PRGn" , "RdBu_r" , "PRGn_r"
# ) , pastel

# %% [markdown]
# sns.set_style("white" , "dark" , "whitegrid" , "darkgrid" , "ticks)

# %% [markdown]
# sns.set_context("paper" , "talk" , "notebook" , "poster")
