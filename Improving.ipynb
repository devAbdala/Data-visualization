# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mpg = pd.read_csv("./data/mpg.csv" , index_col = 0)
mpg
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model_year  \
# mpg
# 18.0          8         307.0       130.0    3504          12.0          70
# 15.0          8         350.0       165.0    3693          11.5          70
# 18.0          8         318.0       150.0    3436          11.0          70
# 16.0          8         304.0       150.0    3433          12.0          70
# 17.0          8         302.0       140.0    3449          10.5          70
# ...         ...           ...         ...     ...           ...         ...
# 27.0          4         140.0        86.0    2790          15.6          82
# 44.0          4          97.0        52.0    2130          24.6          82
# 32.0          4         135.0        84.0    2295          11.6          82
# 28.0          4         120.0        79.0    2625          18.6          82
# 31.0          4         119.0        82.0    2720          19.4          82
#
#       origin                       name
# mpg
# ...

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn")
sns.set_context("poster")
sns.scatterplot(x = 'weight' , y = 'horsepower' , data = mpg , hue = 'cylinders')
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn")
sns.set_context("poster")
sns.scatterplot(x = 'weight' , y = 'horsepower' , data = mpg , hue = 'model_year')
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn")
sns.set_context("poster")
sns.scatterplot(x = 'weight' , y = 'horsepower' , data = mpg , hue = 'origin')
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn")
sns.set_context("poster")
sns.regplot(x = 'weight' , y = 'horsepower' , data = mpg)
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("RdBu")
sns.set_context("talk")
sns.swarmplot(x = 'origin' , y = 'weight' , data = mpg)
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn")
sns.set_context("notebook")
sns.lmplot(x = 'weight' , y = 'horsepower' , data = mpg , hue = 'origin')
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn")
sns.set_context("notebook")
sns.kdeplot(x = mpg['weight'] , data = mpg , fill = True )
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn_r")
sns.set_context("notebook")
sns.kdeplot(x = mpg['acceleration'] , data = mpg , fill = True , hue = 'origin')
plt.show()

# %%
pollution = pd.read_csv("./data/Pollution.csv" , index_col=0)
pollution
# Out:
#                            year  month  day     CO   NO2     O3    SO2
# city
# Cincinnati                 2012      1    1  0.245  20.0  0.030   4.20
# Cincinnati                 2012      1    2  0.185   9.0  0.025   6.35
# Cincinnati                 2012      1    3  0.335  31.0  0.025   4.25
# Cincinnati                 2012      1    4  0.305  25.0  0.016  17.15
# Cincinnati                 2012      1    5  0.345  21.0  0.016  11.05
# ...                         ...    ...  ...    ...   ...    ...    ...
# Vandenberg Air Force Base  2015     12  361  0.300   1.0  0.038   0.65
# Vandenberg Air Force Base  2015     12  362  0.300   1.0  0.039   0.50
# Vandenberg Air Force Base  2015     12  363  0.300   1.0  0.037   0.65
# Vandenberg Air Force Base  2015     12  364  0.300   1.0  0.038   0.65
# Vandenberg Air Force Base  2015     12  365  0.300   1.0  0.039   0.65
#
# [8888 rows x 7 columns]

# %%
pollution.index
# Out:
# Index(['Cincinnati', 'Cincinnati', 'Cincinnati', 'Cincinnati', 'Cincinnati',
#        'Cincinnati', 'Cincinnati', 'Cincinnati', 'Cincinnati', 'Cincinnati',
#        ...
#        'Vandenberg Air Force Base', 'Vandenberg Air Force Base',
#        'Vandenberg Air Force Base', 'Vandenberg Air Force Base',
#        'Vandenberg Air Force Base', 'Vandenberg Air Force Base',
#        'Vandenberg Air Force Base', 'Vandenberg Air Force Base',
#        'Vandenberg Air Force Base', 'Vandenberg Air Force Base'],
#       dtype='object', name='city', length=8888)

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn_r")
sns.set_context("notebook")
sns.scatterplot(x = 'NO2' , y = 'SO2' , data = pollution)
plt.text(30 , 138 , 'look at this outlier' , fontdict= {"ha" : "left" , "size" : "large"})
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn_r")
sns.set_context("notebook")
sns.scatterplot(x = 'NO2' , y = 'SO2' , data = pollution ,  hue = 'city')
plt.annotate('Look at this outlier for Cincinnati', xy = (30 , 105) , xytext = (40 , 120) , arrowprops = {"facecolor" : "gray" , "width" : 4} , backgroundcolor = 'white')
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn_r")
sns.set_context("notebook")
sns.barplot(y = pollution.index , x = 'CO' , data = pollution )
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn_r")
sns.set_context("notebook")
sns.barplot(x = pollution.index , y = 'NO2' , data = pollution )
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn_r")
sns.set_context("notebook")
sns.lineplot(x = pollution.index , y = pollution['NO2'] , hue = pollution['year'])
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn_r")
sns.set_context("notebook")
sns.lineplot(x = pollution['month'] , y = pollution['NO2'] , hue = pollution['year'] , data = pollution)
plt.show()

# %%
plt.figure(figsize = (20 , 5))
sns.set_style("darkgrid")
sns.set_palette("PRGn")
sns.set_context("notebook")
sns.barplot(x = pollution['year'] , y = 'NO2' , data = pollution )
plt.show()
